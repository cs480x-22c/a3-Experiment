# %%
import pandas as pd

df = pd.read_csv('experiment_data.csv')
df.drop(df[df['true_percentage'] == 0].index, inplace = True)

# %%
import numpy as np

df_pie = df[df['Chart_Type'] == "pie"]
df_pie['log2error'] = np.log2(np.abs(df_pie['guessed_percentage']-df_pie['true_percentage'])+(1/8))
df_pie
# Out:
# <ipython-input-54-b9796b5aff33>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pie['log2error'] = np.log2(np.abs(df_pie['guessed_percentage']-df_pie['true_percentage'])+(1/8))
#      Person_ID  Trial Chart_Type  true_percentage_unrounded  true_percentage  \
# 0          474      1        pie                  44.262295               44
# 2          474      3        pie                  35.714286               36
# 6          474      7        pie                  33.333333               33
# 12         474     13        pie                   8.988764                9
# 15         474     16        pie                  21.951220               22
# ..         ...    ...        ...                        ...              ...
# 812        749     83        pie                  59.523810               60
# 817        749     88        pie                  21.428571               21
# 819        749     90        pie                  13.684211               14
# 821        749     92        pie                  13.333333               13
# 830        749    101        pie                 100.000000              100
#
#      guessed_percentage  log2error
# 0                  50.0   2.614710
# 2                  25.0   3.475733
# 6                  30.0   1.643856
# 12                 20.0   3.475733
# 15                 27.0   2.357552
# ..                  ...        ...
# 812                66.0   2.614710
# 817                17.0   2.044394
# 819                10.0   2.044394
# 821                15.0   1.087463
# 830                98.0   1.087463
#
# [200 rows x 7 columns]

# %%
df_pie3D = df[df['Chart_Type']== 'pie3D']
df_pie3D['log2error'] = np.log2(np.abs(df_pie3D['guessed_percentage']-df_pie3D['true_percentage'])+(1/8))
df_pie3D
# Out:
# <ipython-input-55-52ef5d74ab1c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pie3D['log2error'] = np.log2(np.abs(df_pie3D['guessed_percentage']-df_pie3D['true_percentage'])+(1/8))
#      Person_ID  Trial Chart_Type  true_percentage_unrounded  true_percentage  \
# 1          474      2      pie3D                   9.859155               10
# 3          474      4      pie3D                  75.555556               76
# 5          474      6      pie3D                  77.777778               78
# 9          474     10      pie3D                   8.750000                9
# 27         474     28      pie3D                  83.333333               83
# ..         ...    ...        ...                        ...              ...
# 818        749     89      pie3D                  93.670886               94
# 820        749     91      pie3D                   8.064516                8
# 822        749     93      pie3D                   4.545455                5
# 823        749     94      pie3D                  56.521739               57
# 827        749     98      pie3D                   3.370787                3
#
#      guessed_percentage  log2error
# 1                  16.0   2.614710
# 3                  75.0   0.169925
# 5                  80.0   1.087463
# 9                  17.0   3.022368
# 27                 89.0   2.614710
# ..                  ...        ...
# 818                98.0   2.044394
# 820                 5.0   1.643856
# 822                 5.0  -3.000000
# 823                61.0   2.044394
# 827                 3.0  -3.000000
#
# [224 rows x 7 columns]

# %%
df_stacked3D = df[df['Chart_Type']== 'stackedBar3D']
df_stacked3D['log2error'] = np.log2(np.abs(df_stacked3D['guessed_percentage']-df_stacked3D['true_percentage'])+(1/8))
df_stacked3D
# Out:
# <ipython-input-56-4441af574d01>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stacked3D['log2error'] = np.log2(np.abs(df_stacked3D['guessed_percentage']-df_stacked3D['true_percentage'])+(1/8))
#      Person_ID  Trial    Chart_Type  true_percentage_unrounded  \
# 4          474      5  stackedBar3D                  22.093023
# 11         474     12  stackedBar3D                  82.417582
# 18         474     19  stackedBar3D                  97.777778
# 23         474     24  stackedBar3D                  60.273973
# 25         474     26  stackedBar3D                  91.666667
# ..         ...    ...           ...                        ...
# 813        749     84  stackedBar3D                  32.203390
# 814        749     85  stackedBar3D                  73.076923
# 825        749     96  stackedBar3D                  92.771084
# 826        749     97  stackedBar3D                  69.230769
# 829        749    100  stackedBar3D                   8.064516
#
#      true_percentage  guessed_percentage  log2error
# 4                 22                15.0   2.832890
# 11                82                75.0   2.832890
# 18                98                86.0   3.599913
# 23                60                73.0   3.714246
# 25                92                82.0   3.339850
# ..               ...                 ...        ...
# 813               32                33.0   0.169925
# 814               73                78.0   2.357552
# 825               93                95.0   1.087463
# 826               69                78.0   3.189825
# 829                8                 5.0   1.643856
#
# [210 rows x 7 columns]

# %%
df_stacked = df[df['Chart_Type']== 'stackedBar']
df_stacked['log2error'] = np.log2(np.abs(df_stacked['guessed_percentage']-df_stacked['true_percentage'])+(1/8))
df_stacked
# Out:
# <ipython-input-57-97ac96acb288>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stacked['log2error'] = np.log2(np.abs(df_stacked['guessed_percentage']-df_stacked['true_percentage'])+(1/8))
#      Person_ID  Trial  Chart_Type  true_percentage_unrounded  true_percentage  \
# 7          474      8  stackedBar                  24.590164               25
# 8          474      9  stackedBar                  32.530120               33
# 10         474     11  stackedBar                  12.500000               13
# 13         474     14  stackedBar                  14.634146               15
# 14         474     15  stackedBar                  30.769231               31
# ..         ...    ...         ...                        ...              ...
# 842        823     12  stackedBar                  77.358491               77
# 843        823     13  stackedBar                  37.878788               38
# 844        823     14  stackedBar                  95.312500               95
# 845        823     15  stackedBar                  36.363636               36
# 846        823     16  stackedBar                  63.888889               64
#
#      guessed_percentage  log2error
# 7                  25.0  -3.000000
# 8                  50.0   4.098032
# 10                 17.0   2.044394
# 13                 30.0   3.918863
# 14                 47.0   4.011227
# ..                  ...        ...
# 842                99.0   4.467606
# 843                20.0   4.179909
# 844                88.0   2.832890
# 845                25.0   3.475733
# 846                50.0   3.820179
#
# [202 rows x 7 columns]

# %%
import scipy.stats as st

data_pie = list(df_pie['log2error'])
data_pie3D = list(df_pie3D['log2error'])
data_stacked3D = list(df_stacked3D['log2error'])
data_stacked = list(df_stacked['log2error'])

# %%
import matplotlib.pyplot as plt
import statistics
from math import sqrt
from scipy.stats import bootstrap

def plot_confidence_interval(x, values, z=1.96, color='#2187bb', horizontal_line_width=0.25):
    mean = statistics.mean(values)
    stdev = statistics.stdev(values)
    data = (values, )
    res = bootstrap(data, np.mean, confidence_level=0.95, n_resamples=1000, random_state=42)
    ci_l, ci_u = res.confidence_interval

    left = x - horizontal_line_width / 2
    top = ci_l
    right = x + horizontal_line_width / 2
    bottom = ci_u
    plt.plot([top, bottom],[x, x], color=color)
    plt.plot([top, top], [left, right], color=color)
    plt.plot([bottom, bottom], [left, right], color=color)
    plt.plot(mean, x, 'o', color='#f44336')

    return mean, ci_l, ci_u


plt.yticks([1, 2, 3, 4], ['pie', 'pie3D', 'stacked3D', 'stacked'])

plt.title('Results')
plt.xlabel('Log Error')
plt.ylabel('Chart Type')
plt.xlim([2.0, 3.0])
plot_confidence_interval(1, data_pie)
plot_confidence_interval(2, data_pie3D)
plot_confidence_interval(3, data_stacked3D)
plot_confidence_interval(4, data_stacked)
plt.show()
